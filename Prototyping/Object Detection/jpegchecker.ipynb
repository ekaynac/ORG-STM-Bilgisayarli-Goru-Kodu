# %%
import os
from PIL import Image
import shutil

# %%
PATH = r"D:\GitHub\Meturone\Meturone\UORG\Object Detection\portable_generator\train"
new_test_path =r"D:\GitHub\Meturone\Meturone\UORG\Object Detection\NewDataset\train"
new_train_path = r"D:\GitHub\Meturone\Meturone\UORG\Object Detection\NewDataset\train"

# %%
for i in os.listdir(PATH):
    img_path = os.path.join(PATH,i)
    try:
        img = Image.open(img_path)
        if img.format == "PNG":
            #img.save(new_test_path, "JPEG")
            print("Bu png amk")
        elif img.format == "JPEG":
            #shutil.copy(img_path,new_test_path)
            print("şükür amk")
    except:
        #shutil.copy(img_path,new_test_path)
        print("{} is not an image".format(i))
# Out:
# Bu png amk
# portable_generator1041.xml is not an image
# Bu png amk
# portable_generator1055.xml is not an image
# Bu png amk
# portable_generator1056.xml is not an image
# Bu png amk
# portable_generator1057.xml is not an image
# Bu png amk
# portable_generator1058.xml is not an image
# Bu png amk
# portable_generator1066.xml is not an image
# Bu png amk
# portable_generator1075.xml is not an image
# Bu png amk
# portable_generator1078.xml is not an image
# Bu png amk
# portable_generator1085.xml is not an image
# Bu png amk
# portable_generator1087.xml is not an image
# Bu png amk
# portable_generator1091.xml is not an image
# Bu png amk
# portable_generator1097.xml is not an image
# Bu png amk
# portable_generator1098.xml is not an image
# Bu png amk
# portable_generator1099.xml is not an image
# Bu png amk
# portable_generator1120.xml is not an image
# Bu png amk
# portable_generator1132.xml is not an image
# Bu png amk
# portable_generator1134.xml is not an image
# Bu png amk
# ...
