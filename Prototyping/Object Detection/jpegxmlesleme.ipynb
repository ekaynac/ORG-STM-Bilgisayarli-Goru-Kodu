# %%
import os

# %%
PATH =  r"D:\GitHub\Meturone\Meturone\UORG\Object Detection\NewDataset\test"

# %%
old_i = []
for i in range(0,len(os.listdir(PATH)),2):
    print(os.listdir(PATH)[i+1])
    if os.listdir(PATH)[i] == os.listdir(PATH)[i+1]:
        print(os.listdir(PATH)[i])
# Out:
# portable_generator1041.xml
# portable_generator1055.xml
# portable_generator1056.xml
# portable_generator1057.xml
# portable_generator1058.xml
# portable_generator1066.xml
# portable_generator1075.xml
# portable_generator1078.xml
# portable_generator1085.xml
# portable_generator1087.xml
# portable_generator1091.xml
# portable_generator1097.xml
# portable_generator1098.xml
# portable_generator1099.xml
# portable_generator1120.xml
# portable_generator1132.xml
# portable_generator1134.xml
# portable_generator1141.xml
# portable_generator1143.xml
# portable_generator1183.xml
# portable_generator1301.xml
# portable_generator1334.xml
# portable_generator1335.xml
# portable_generator1354.xml
# portable_generator1355.xml
# portable_generator1356.xml
# portable_generator1357.xml
# portable_generator1360.xml
# portable_generator1362.xml
# portable_generator1363.xml
# portable_generator1422.xml
# portable_generator1424.xml
# portable_generator1428.xml
# portable_generator1436.xml
# ...
